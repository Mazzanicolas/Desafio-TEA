# %%
import missingno as msn
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/formatted_data.csv')
data = data.drop(['Unnamed: 0', 'id'], axis=1)

# %%
msn.bar(data)

# %%
msn.matrix(data)
